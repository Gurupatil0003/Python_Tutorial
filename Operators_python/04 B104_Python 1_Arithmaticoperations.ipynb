# %% [markdown]
# # PYTHON

# %%
India= 12

# %%
India
# Out:
# 12

# %%
a='India'

# %%
a
# Out:
# 'India'

# %%
id(a)
# Out:
# 473507051824

# %% [markdown]
# # GURU

# %%
3+5
# Out:
# 8

# %%
12/5
# Out:
# 2.4

# %%
12//5
# Out:
# 2

# %%
6-7
# Out:
# -1

# %%
5/6
# Out:
# 0.8333333333333334

# %%
5*7
# Out:
# 35

# %%
12/5
# Out:
# 2.4

# %% [markdown]
# # FLOOR DIVISION OR INT DIVISION

# %%
12//5
# Out:
# 2

# %% [markdown]
# # Modulus Opearator

# %%
12%5
# Out:
# 2

# %%
1 + 3 + 4 + 5
# Out:
# 13

# %%
3.4 + 3. + 5.6 - 9.5
# Out:
# 2.5

# %%
3.4 * 4.5 * (5 + 2)
# Out:
# 107.1

# %%
10 / 5
# Out:
# 2.0

# %%
12 / 5
# Out:
# 2.4

# %%
13 // 5
# Out:
# 2

# %%
27.5 // 2
# Out:
# 13.0

# %%
15 // 5
# Out:
# 3

# %%
10 % 3
# Out:
# 1

# %%
20 % 4
# Out:
# 0

# %%
12 % 5
# Out:
# 2

# %%
5 ** 2
# Out:
# 25

# %%
2 ** 3
# Out:
# 8

# %%
3 ** 4
# Out:
# 81

# %% [markdown]
# # String: Group of Characters (a-z, A-Z , Special symbol)

# %%
'1 2 3 4'
# Out:
# '1 2 3 4'

# %% [markdown]
# Addition

# %%
2+4
# Out:
# 6

# %% [markdown]
# Concatenate

# %%
'India' + 'is great'
# Out:
# 'Indiais great'

# %%
'5' + 'India'
# Out:
# '5India'

# %%
5 * 'India'
# Out:
# 'IndiaIndiaIndiaIndiaIndia'

# %%
" %$#@!*^"
# Out:
# ' %$#@!*^'

# %%
'INSOFE'
# Out:
# 'INSOFE'

# %%
'Arpit'
# Out:
# 'Arpit'

# %%
"Arpit"
# Out:
# 'Arpit'

# %%
"'Arpit'"
# Out:
# "'Arpit'"

# %% [markdown]
# Arpit

# %%
'Arpit'
# Out:
# 'Arpit'

# %% [raw]
# Arpit

# %%
"Hello"
# Out:
# 'Hello'

# %%
"Hello" + "  World"
# Out:
# 'Hello  World'

# %%
"Hello"+ '4'
# Out:
# 'Hello4'

# %%
"hello"+'5'
# Out:
# 'hello5'

# %%
"hello "*6
# Out:
# 'hello hello hello hello hello hello '

# %%
"Hello"*4
# Out:
# 'HelloHelloHelloHello'

# %%
"Hello" + "World" + str(3)
# Out:
# 'HelloWorld3'

# %%
a@3=9
# Out:
#   File "<ipython-input-51-325379d2a8bf>", line 1
#     a@3=9
#     ^
# SyntaxError: cannot assign to operator

# %%
a@ = 0
# Out:
#   File "<ipython-input-6-4d4a0e714c73>", line 1
#     a@ = 0
#        ^
# SyntaxError: invalid syntax

# %%
_3=7

# %%
3a=9
# Out:
#   File "<ipython-input-49-eea3fa69a8bf>", line 1
#     3a=9
#      ^
# SyntaxError: invalid syntax

# %%
_fg=3

# %%
fg=4

# %%
df=4

# %%
a=3

# %%
a
# Out:
# 3

# %%
print(a)
# Out:
# 3

# %%
a=3
b=5
c=a+b
c
# Out:
# 8
