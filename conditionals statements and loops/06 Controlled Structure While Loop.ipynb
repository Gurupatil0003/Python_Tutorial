# %% [markdown]
# <h6><div style="font-family: Trebuchet MS; background-color: #1b191d; color: #FFFFFF; padding: 12px; font-size: 35px; line-height: 1.5;text-align: center; line-height: 1.;">🅶🆄 🆁🅰🅽🅽🅰 🅶🅾🆄🅳🅰--🅳🅰🆃🅰🆂🅲🅸🅴🅽🆃 👨‍💻</div> </h6>

# %% [raw]
# The difference between for loop and while loop is that in for loop the number of iterations to be done is already known and is used to obtain a certain result whereas in while loop the command runs until a certain condition is reached and the statement is proved to be false.

# %% [raw]
# For Loop:
#
# 1. Once the statement(s) is executed then after increment is done.
#
# 2. It is normally used when the number of iterations is known.
#
#
#
# While Loop:
#
# 1. Increment can be done before or after the execution of the statement(s).
#
# 2. It is normally used when the number of iterations is unknown.

# %% [markdown]
# <h6><div style="font-family: Trebuchet MS; background-color: #1b191d; color: #FFFFFF; padding: 12px; font-size: 35px; line-height: 1.5;text-align: center; line-height: 1.;">🆆🅷🅸🅻🅴--🅻🅾🅾🅿--🧨💥</div> </h6>

# %% [markdown]
# # Python While loop

# %% [raw]
# 1. The Python while loop allows a part of the code to be executed until the given condition returns false. It is also known as a pre-tested loop.
#
# 2. It can be viewed as a repeating if statement. When we don't know the number of iterations then the while loop is most effective to use.
#
# 3. Python While Loop is used to execute a block of statements repeatedly until a given condition is satisfied.
#
# 4. And when the condition becomes false, the line immediately after the loop in the program is executed.
#
# 5. While loop falls under the category of indefinite iteration. Indefinite iteration means that the number of times the loop is executed isn’t specified explicitly in advance.

# %% [raw]
# The syntax of python’s while loop is:¶
#
# while expression:
#    statement(s)

# %% [raw]
# The ‘condition’ will be the criteria based on which the loop body will be executed.
#
# Till the condition holds true, the loop body is executed.
#
# As soon as it becomes false, python will stop executing the loop body.

# %% [markdown]
# <h2><div style="font-family: Trebuchet MS; background-color: #176BA0;; color: #FFFFFF; padding: 12px; font-size: 35px; line-height: 1.5;text-align: center; line-height: 1.;"> Flow Chart📈 </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](3.png)

# %%
count = 0

while count < 5:
    print(count)
    count = count + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n = int(input("Enter number N :"))
sum = 0
temp = n
while n > 0 :
  sum = sum + n
  n = n - 1
print("Sum of",temp,"numbers is:",sum)
# Out:
# Enter number N :5
# Sum of 5 numbers is: 15

# %%
# product of n numbers using while loop
n = int(input("enter the number: "))
prod = 1
temp = n
while n>0:
    prod = prod*n
    n = n-1
print("Product of",temp,'numbers is : ', prod)
# Out:
# enter the number: 4
# Product of 4 numbers is :  24

# %% [raw]
# Here, the above code is for printing the sum of n numbers as entered by the user. We don’t know here what will be the number that the user will enter.
#
# So, we shall use a while loop in order to print the sum of ‘n’ numbers. First, we take ‘n’ as input from the user.
#
# Then we have two variables, ‘sum’ , which will calculate the total summation and ‘temp’ for storing the value of ‘n’.
#
# Inside the while loop, the condition to be fulfilled is that the value of ‘n’ should always be greater than zero.
#
# Inside the loop, we add the value of ‘n’ to ‘sum’ and then decrement ‘n’. While the value of ‘n’ will become zero, the while loop will stop executing and then print the ‘sum’ variable.

# %%
#Exercise:1 print your name till n = 5 using while loop

# %%
##Exercise:2 print even numbers from 1 to 10

# %%
# Python program to illustrate
# while loop
count = 0
while (count < 3):
	count = count + 1
	print("Hello India")
# Out:
# Hello India
# Hello India
# Hello India

# %%
#Example 2: Python while loop with list

# checks if list still
# contains any element
a = [1, 2, 3, 4]
 
while a:
    print(a.pop())
# Out:
# 4
# 3
# 2
# 1

# %%
tech_companies = ['Google', 'Apple', 'Facebook', 'Uber', 'Intel']
list_len = len(tech_companies)

list_len
# Out:
# 5

# %%
count = 0

while count < list_len:
    print(tech_companies[count])
    count = count + 1
# Out:
# Google
# Apple
# Facebook
# Uber
# Intel

# %%
# While Loop Example

dates = [1982, 1980, 1973, 2000]

i = 0
year = 0

while year != 1973:
    year = dates[i]
    i = i + 1
    print(year)

print("It took ", i ,"repetitions to get out of loop.")
# Out:
# 1982
# 1980
# 1973
# It took  3 repetitions to get out of loop.

# %%
# Why this code is not working ? 
count = 6
while count < 5:
    print(count)

# %%
# This will cause an infinite loop, press the stop button on the menu bar
count = 4

while count < 5:
    print(count)
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# ...

# %%
count = 4

while count < 5:
    print(count)
    
    count = 10
# Out:
# 4

# %%
count = 0

while count < 5:
    print(count)
    count = count + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
tech_companies = ['Google', 'Apple', 'Facebook', 'Uber', 'Intel']
list_len = len(tech_companies)

list_len
# Out:
# 5

# %%
count = 0

while count < list_len:
    print(tech_companies[count])
    
    count = count + 1
# Out:
# Google
# Apple
# Facebook
# Uber
# Intel

# %%
count = 0

while count < len(tech_companies):
    print(tech_companies[count])
    
    count = count + 1
# Out:
# Google
# Apple
# Facebook
# Uber
# Intel

# %%
tech_companies
# Out:
# ['Google', 'Apple', 'Facebook', 'Uber', 'Intel']

# %%
tech_companies[count]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11020/1611328077.py in <module>
# ----> 1 tech_companies[count]
#
# NameError: name 'tech_companies' is not defined

# %%
count = 0
while count < 10:
    print(tech_companies[count])
    
    count = count + 1
# Out:
# Google
# Apple
# Facebook
# Uber
# Intel
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-a0884e6dc912> in <module>
#       1 count = 0
#       2 while count < 10:
# ----> 3     print(tech_companies[count])
#       4
#       5     count = count + 1
#
# IndexError: list index out of range

# %%
# Decrement the count
count = 7

while count >= 0:
    print(count)
    
    count = count - 3
# Out:
# 7
# 4
# 1

# %%
inc_count = 0
dec_count = 10

while inc_count > 5 or dec_count > 5:
    print(inc_count, dec_count)
    
    inc_count = inc_count + 1
    dec_count = dec_count - 2

print('Final count values ', inc_count, dec_count)
# Out:
# 0 10
# 1 8
# 2 6
# Final count values  3 4

# %%
num = 8

while num < 10:
    num = int(input('Enter a number: '))
    
    print('You entered: ', num)
    
print('\nFinal number which caused us to break out of the loop', num)
# Out:
# Enter a number: 5
# You entered:  5
# Enter a number: 45
# You entered:  45
#
# Final number which caused us to break out of the loop 45

# %% [markdown]
# # Single statement while block

# %% [raw]
# Just like the if block, if the while block consists of a single statement we can declare the entire loop in a single line. If there are multiple statements in the block that makes up the loop body, they can be separated by semicolons (;).

# %%
# Python program to illustrate
# Single statement while block
count = 0
while (count < 5): count += 1; print("Hello India")
# Out:
# Hello India
# Hello India
# Hello India
# Hello India
# Hello India

# %% [markdown]
# # While loop with else

# %% [raw]
# As discussed above, while loop executes the block until a condition is satisfied. When the condition becomes false, the statement immediately after the loop is executed. The else clause is only executed when your while condition becomes false. If you break out of the loop, or if an exception is raised, it won’t be executed.
#
# Note: The else block just after for/while is executed only when the loop is NOT terminated by a break statement.

# %%
# Python program to demonstrate
# while-else loop

i = 0
while i < 4:
	i += 1
	print(i)
else: # Executed because no break in for
	print("No Break\n")
# Out:
# 1
# 2
# 3
# 4
# No Break

# %%
i = 0
while i < 4:
	i += 1
	print(i)
	break
else: # Not executed as there is a break
	print("No Break")
# Out:
# 1
